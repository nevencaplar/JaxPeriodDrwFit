# %%
from tinygp import GaussianProcess
from tinygp.kernels import quasisep

import jax
from jax import export

import numpy as np

# %%
def build_gp_drw(theta, t, y, yerr):
    """Build a Gaussian Process model with the damped random walk kernel.

    Parameters
    ----------
    theta : array-like, (2,)
        Array of float values representing the parameters for the kernel.
    t : array-like
        Time domain data for the Gaussian Process.
    y : array-like
        Observations corresponding to the time domain data.
    yerr : array-like
        Uncertainties (errors) associated with the observations.

    Returns
    -------
    gp : GaussianProcess
        Gaussian Process model with the damped random walk kernel.

    Example
    -------
    theta = [0.5, -1.0, 0.8, -2.0]
    gp = build_gp(theta, t, y, yerr)
    """

    # assert len(theta) == 2

    log_drw_scale = theta[0]
    log_drw_amp = theta[1]

    exp_kernel = quasisep.Exp(
        scale=10**log_drw_scale, sigma=10**log_drw_amp)

    kernel = exp_kernel
 
    return GaussianProcess(kernel, t, diag=yerr, mean=np.mean(y), assume_sorted=True)

# %%
theta_init = np.array([np.log10(100), 2.0])
t_single = np.linspace(0, 10, 100)
y_single = np.sin(t_single)
yerr_single = 0.1 * np.ones_like(y_single)

# %%
jaxpr = jax.make_jaxpr(jax.jit(build_gp_drw))(theta_init, t_single, y_single, yerr_single)
print(jaxpr.pretty_print(source_info=True))
# Out:
# { lambda ; a:f32[2] b:f32[100] c:f32[100] d:f32[100]. let
#     e:f32[] f:f32[] g:f32[] h:f32[100] i:f32[100] j:f32[100,1] k:f32[100,1] l:f32[100,1,1]
#       m:f32[100] n:f32[100,1] o:f32[100,1] p:f32[100,1,1] = pjit[                            # /tmp/ipykernel_64954/3436479300.py:1:8 (<module>)
#       name=build_gp_drw
#       jaxpr={ lambda ; q:f32[2] r:f32[100] s:f32[100] t:f32[100]. let
#           u:f32[1] = slice[limit_indices=(1,) start_indices=(0,) strides=None] q             # /tmp/ipykernel_64954/1532116811.py:28:20 (build_gp_drw)
#           v:f32[] = squeeze[dimensions=(0,)] u                                               # /tmp/ipykernel_64954/1532116811.py:28:20 (build_gp_drw)
#           w:f32[1] = slice[limit_indices=(2,) start_indices=(1,) strides=None] q             # /tmp/ipykernel_64954/1532116811.py:29:18 (build_gp_drw)
#           x:f32[] = squeeze[dimensions=(0,)] w                                               # /tmp/ipykernel_64954/1532116811.py:29:18 (build_gp_drw)
#           y:f32[] = pow 10.0 v                                                               # /tmp/ipykernel_64954/1532116811.py:32:14 (build_gp_drw)
#           z:f32[] = pow 10.0 x                                                               # /tmp/ipykernel_64954/1532116811.py:32:39 (build_gp_drw)
#           ba:f32[] = reduce_sum[axes=(0,)] s                                                 # /tmp/ipykernel_64954/1532116811.py:36:54 (build_gp_drw)
#           bb:f32[] = div ba 100.0                                                            # /tmp/ipykernel_64954/1532116811.py:36:54 (build_gp_drw)
#           bc:f32[100] = broadcast_in_dim[broadcast_dimensions=() shape=(100,)] bb            # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bd:f32[1,1] = broadcast_in_dim[broadcast_dimensions=() shape=(1, 1)] 1.0           # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           be:f32[1] = slice[limit_indices=(1,) start_indices=(0,) strides=None] r            # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bf:f32[] = squeeze[dimensions=(0,)] be                                             # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bg:f32[99] = slice[                                                                # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             limit_indices=(99,)
#             start_indices=(0,)
#             strides=None
#           ] r
#           bh:f32[100] = pjit[                                                                # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             name=append
#             jaxpr={ lambda ; bi:f32[] bj:f32[99]. let
#                 bk:f32[1] = reshape[dimensions=None new_sizes=(1,)] bi                       # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                 bl:f32[100] = concatenate[dimension=0] bk bj                                 # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#               in (bl,) }
#           ] bf bg
#           bm:f32[100] = sub r bh                                                             # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bn:f32[100,1,1] = broadcast_in_dim[                                                # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             broadcast_dimensions=(0,)
#             shape=(100, 1, 1)
#           ] bm
#           bo:f32[100,1,1] = neg bn                                                           # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bp:f32[100,1,1] = div bo y                                                         # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bq:f32[100,1,1] = exp bp                                                           # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           br:f32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] z                 # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bs:f32[100,1] = broadcast_in_dim[                                                  # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             broadcast_dimensions=(1,)
#             shape=(100, 1)
#           ] br
#           bt:f32[100,1] = dot_general[                                                       # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             dimension_numbers=(([1], [0]), ([], []))
#             preferred_element_type=float32
#           ] bs bd
#           bu:f32[100,1] = mul bt bs                                                          # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bv:f32[100] = reduce_sum[axes=(1,)] bu                                             # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#           bw:f32[100,1] = dot_general[                                                       # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             dimension_numbers=(([1], [1]), ([0], [0]))
#             preferred_element_type=float32
#           ] bt bq
#           bx:f32[100] = pjit[                                                                # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             name=elementwise_add
#             jaxpr={ lambda ; by:f32[100] bz:f32[100,1] ca:f32[100,1] cb:f32[100,1,1]
#                 cc:f32[100]. let
#                 cd:f32[100] = add by cc                                                      # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#               in (cd,) }
#           ] bv bw bs bq t
#           ce:f32[100] cf:f32[100,1] = pjit[                                                  # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#             name=cholesky
#             jaxpr={ lambda ; cg:f32[100] ch:f32[100,1] ci:f32[100,1] cj:f32[100,1,1]. let
#                 ck:f32[1,1] = slice[                                                         # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                   limit_indices=(1, 1)
#                   start_indices=(0, 0)
#                   strides=None
#                 ] ci
#                 cl:f32[1] = squeeze[dimensions=(0,)] ck                                      # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                 cm:f32[1,1] = slice[                                                         # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                   limit_indices=(1, 1)
#                   start_indices=(0, 0)
#                   strides=None
#                 ] ci
#                 cn:f32[1] = squeeze[dimensions=(0,)] cm                                      # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                 co:f32[1,1] = broadcast_in_dim[                                              # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                   broadcast_dimensions=(0,)
#                   shape=(1, 1)
#                 ] cl
#                 cp:f32[1,1] = broadcast_in_dim[                                              # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                   broadcast_dimensions=(1,)
#                   shape=(1, 1)
#                 ] cn
#                 _:f32[1,1] = mul co cp                                                       # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                 cq:f32[1,1] = broadcast_in_dim[                                              # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                   broadcast_dimensions=()
#                   shape=(1, 1)
#                 ] 0.0
#                 _:f32[1,1] cr:f32[100] cs:f32[100,1] = scan[                                 # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                   _split_transpose=False
#                   jaxpr={ lambda ; ct:f32[1,1] cu:f32[] cv:f32[1] cw:f32[1] cx:f32[1,1]. let
#                       cy:f32[1] = dot_general[                                               # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                         dimension_numbers=(([0], [0]), ([], []))
#                         preferred_element_type=float32
#                       ] cv ct
#                       cz:f32[] = dot_general[                                                # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                         dimension_numbers=(([0], [0]), ([], []))
#                         preferred_element_type=float32
#                       ] cy cv
#                       da:f32[] = sub cu cz                                                   # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                       db:f32[] = sqrt da                                                     # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                       dc:f32[1,1] = transpose[permutation=(1, 0)] cx                         # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                       dd:f32[1,1] = dot_general[                                             # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                         dimension_numbers=(([1], [0]), ([], []))
#                         preferred_element_type=float32
#                       ] ct dc
#                       de:f32[1] = dot_general[                                               # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                         dimension_numbers=(([0], [0]), ([], []))
#                         preferred_element_type=float32
#                       ] cv dd
#                       df:f32[1] = sub cw de                                                  # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                       dg:f32[1] = div df db                                                  # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                       dh:f32[1,1] = dot_general[                                             # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                         dimension_numbers=(([1], [0]), ([], []))
#                         preferred_element_type=float32
#                       ] cx dd
#                       di:f32[1,1] = broadcast_in_dim[                                        # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                         broadcast_dimensions=(0,)
#                         shape=(1, 1)
#                       ] dg
#                       dj:f32[1,1] = broadcast_in_dim[                                        # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                         broadcast_dimensions=(1,)
#                         shape=(1, 1)
#                       ] dg
#                       dk:f32[1,1] = mul di dj                                                # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                       dl:f32[1,1] = add dh dk                                                # /tmp/ipykernel_64954/1532116811.py:36:11 (build_gp_drw)
#                     in (dl, db, dg) }
#                   length=100
#                   linear=(False, False, False, False, False)
#                   num_carry=1
#                   num_consts=0
#                   reverse=False
#                   unroll=1
#                 ] cq cg ch ci cj
#               in (cr, cs) }
#           ] bx bw bs bq
#         in (y, z, bb, bc, bx, bw, bs, bq, ce, bw, cf, bq) }
#     ] a b c d
#   in (e, f, b, g, h, d, b, i, j, k, l, m, n, o, p) }
